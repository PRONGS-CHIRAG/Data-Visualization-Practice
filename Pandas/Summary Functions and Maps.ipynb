# %%
import pandas as pd

# %%
wine_data = pd.read_csv("Datasets/winemag-data_first150k.csv",index_col=0) #index col used when we need to specify the index column
wine_data.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
'''Summary functionality is provided by the describe function,it is applied on lists usually column names'''
wine_data.description.describe()
# Out:
# count                                                150930
# unique                                                97821
# top       A little bit funky and unsettled when you pop ...
# freq                                                      6
# Name: description, dtype: object

# %%
wine_data.price.describe()
# Out:
# count    137235.000000
# mean         33.131482
# std          36.322536
# min           4.000000
# 25%          16.000000
# 50%          24.000000
# 75%          40.000000
# max        2300.000000
# Name: price, dtype: float64

# %%
wine_data.points.std()
# Out:
# 3.2223917589832167

# %%
wine_data.winery.value_counts() # counts the frequency of every item
# Out:
# Williams Selyem          374
# Testarossa               274
# DFJ Vinhos               258
# Chateau Ste. Michelle    225
# Columbia Crest           217
#                         ...
# Republic of Wine           1
# Prince Michel              1
# Glass House                1
# Jones von Drehle           1
# White Knot                 1
# Name: winery, Length: 14810, dtype: int64

# %%
wine_data.designation.unique()
# Out:
# array(["Martha's Vineyard", 'Carodorum Selección Especial Reserva',
#        'Special Selected Late Harvest', ..., 'Delaware Dolce',
#        'Presidential 20-year old tawny', 'Bungalow Red'], dtype=object)

# %%
#maps
points_mean = wine_data.points.mean()
wine_data.points.map(lambda p: p - points_mean)
# Out:
# 0         8.111582
# 1         8.111582
# 2         8.111582
# 3         8.111582
# 4         7.111582
#             ...
# 150925    3.111582
# 150926    3.111582
# 150927    3.111582
# 150928    2.111582
# 150929    2.111582
# Name: points, Length: 150930, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - points_mean
    return row
wine_data.apply(remean_points,axis='columns')
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation    points  price  \
# 0                          Martha's Vineyard  8.111582  235.0
# ...
